# %%
#This will be the team of the year code for Premier League 2018-2019

# %%
import pandas as pd
import numpy as np

data=pd.read_csv('E:/PYTHON/WinterProject/england-premier-league-players-2018-to-2019-stats.csv')
#print(data)
#print(list(data.columns))
data_we_need=data[["full_name","position","Current Club","appearances_overall","goals_overall","assists_overall","penalty_goals","penalty_misses", 'clean_sheets_overall','yellow_cards_overall', 'red_cards_overall','Total_Price']]
print(data_we_need)
# Out:
#                     full_name    position       Current Club  \
# 0                David de Gea  Goalkeeper  Manchester United
# 1              Matteo Darmian    Defender  Manchester United
# 2             Victor Lindelof    Defender  Manchester United
# 3                   Luke Shaw    Defender  Manchester United
# 4                 Eric Bailly    Defender  Manchester United
# ..                        ...         ...                ...
# 394   Alex Oxlade-Chamberlain  Midfielder          Liverpool
# 395  Anthony Driscoll-Glennon    Defender            Burnley
# 396              Mark Travers  Goalkeeper    AFC Bournemouth
# 397               Luke Dreher  Midfielder     Crystal Palace
# 398             Kelland Watts  Midfielder   Newcastle United
#
#      appearances_overall  goals_overall  assists_overall  penalty_goals  \
# 0                     38              0                0              0
# 1                      6              0                0              0
# 2                     30              1                1              0
# 3                     29              1                4              0
# 4                     12              0                0              0
# ..                   ...            ...              ...            ...
# 394                    2              0                0              0
# 395                    0              0                0              0
# 396                    2              0                0              0
# 397                    1              0                0              0
# 398                    0              0                0              0
#
#      penalty_misses  clean_sheets_overall  yellow_cards_overall  \
# 0                 0                     7                     1
# 1                 0                     1                     0
# 2                 0                     6                     1
# 3                 0                     6                    11
# 4                 0                     3                     1
# ..              ...                   ...                   ...
# 394               0                     2                     0
# 395               0                     0                     0
# 396               0                     1                     0
# 397               0                     0                     0
# 398               0                     0                     0
#
#      red_cards_overall  Total_Price
# 0                    0          5.3
# 1                    0          4.9
# 2                    0          5.3
# 3                    0          5.4
# 4                    1          4.9
# ..                 ...          ...
# 394                  0          6.2
# 395                  0          3.9
# 396                  0          4.2
# 397                  0          4.3
# 398                  0          3.9
#
# [399 rows x 12 columns]

# %%
goalkeepers=data_we_need[data_we_need["position"]=="Goalkeeper"]
count_row = goalkeepers.shape[0]

def calculate_points(row):
    return ((row["appearances_overall"]*2)+(row["goals_overall"]*6)+(row["assists_overall"]*3)+(row["penalty_goals"]*5)+(row["penalty_misses"]*-2)+(row["clean_sheets_overall"]*4)+(row['yellow_cards_overall']*-1)+(row['red_cards_overall']*-2))

#print(goalkeepers.apply(calculate_points,axis=1))
goalkeepers["Points"] = goalkeepers.apply(calculate_points,axis=1)

descending_goalkeepers = goalkeepers.sort_values('Points',ascending=False)
count = 2
selected_goalkeepers = descending_goalkeepers.head(2)
#for i in range(count):
    
#total_points = []
#goalkeepers["Total Points"] = ((goalkeepers["appearances_overall"]*2)+(goalkeepers["goals_overall"]*6)+(goalkeepers["assists_overall"]*3)+(goalkeepers["penalty_goals"]*5)+(goalkeepers["penalty_misses"]*-2)+(goalkeepers["clean_sheets_overall"]*4)+(goalkeepers['yellow_cards_overall']*-1)+(goalkeepers['red_cards_overall']*-2))
#print("Before")
#print(goalkeepers)
#print("After")
#print(descending_goalkeepers)
print("Selected goalkeepers")
print(selected_goalkeepers)
# Out:
# Selected goalkeepers
#           full_name    position     Current Club  appearances_overall  \
# 184  Alisson Becker  Goalkeeper        Liverpool                   38
# 263         Ederson  Goalkeeper  Manchester City                   38
#
#      goals_overall  assists_overall  penalty_goals  penalty_misses  \
# 184              0                0              0               0
# 263              0                1              0               0
#
#      clean_sheets_overall  yellow_cards_overall  red_cards_overall  \
# 184                    21                     1                  0
# 263                    20                     2                  0
#
#      Total_Price  Points
# 184          6.2     159
# 263          6.0     157
# <ipython-input-4-bd9da31dcaa7>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   goalkeepers["Points"] = goalkeepers.apply(calculate_points,axis=1)

# %%
#defenders idhar daalo

defender=data_we_need[data_we_need["position"]=="Defender"]
count_row = defender.shape[0]

def calculate_points(row):
    return ((row["appearances_overall"]*2)+(row["goals_overall"]*6)+(row["assists_overall"]*3)+(row["penalty_goals"]*5)+(row["penalty_misses"]*-2)+(row["clean_sheets_overall"]*4)+(row['yellow_cards_overall']*-1)+(row['red_cards_overall']*-2))

#print(defender.apply(calculate_points,axis=1))
defender["Points"] = defender.apply(calculate_points,axis=1)

descending_defender = defender.sort_values('Points',ascending=False)
count = 2
selected_defender = descending_defender.head(5)
#for i in range(count):
    
#total_points = []
#goalkeepers["Total Points"] = ((goalkeepers["appearances_overall"]*2)+(goalkeepers["goals_overall"]*6)+(goalkeepers["assists_overall"]*3)+(goalkeepers["penalty_goals"]*5)+(goalkeepers["penalty_misses"]*-2)+(goalkeepers["clean_sheets_overall"]*4)+(goalkeepers['yellow_cards_overall']*-1)+(goalkeepers['red_cards_overall']*-2))
#print("Before")
#print(defender)
#print("After")
#print(descending_defender)
#print("Selected defenders")
print(selected_defender)
# Out:
#                   full_name  position     Current Club  appearances_overall  \
# 185         Virgil van Dijk  Defender        Liverpool                   38
# 186        Andrew Robertson  Defender        Liverpool                   36
# 266         Aymeric Laporte  Defender  Manchester City                   35
# 188  Trent Alexander-Arnold  Defender        Liverpool                   29
# 102             David Luiz   Defender          Chelsea                   36
#
#      goals_overall  assists_overall  penalty_goals  penalty_misses  \
# 185              4                2              0               0
# 186              0               11              0               0
# 266              3                3              0               0
# 188              1               12              0               0
# 102              3                2              0               0
#
#      clean_sheets_overall  yellow_cards_overall  red_cards_overall  \
# 185                    21                     1                  0
# 186                    21                     4                  0
# 266                    18                     3                  0
# 188                    16                     3                  0
# 102                    16                     3                  0
#
#      Total_Price  Points
# 185          6.5     189
# 186          7.0     185
# 266          6.3     166
# 188          7.8     161
# 102          5.7     157
# <ipython-input-5-1edd4bc4e1c1>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   defender["Points"] = defender.apply(calculate_points,axis=1)

# %%
#midfielders idhar daalo

midfielder=data_we_need[data_we_need["position"]=="Midfielder"]
count_row = midfielder.shape[0]

def calculate_points(row):
    return ((row["appearances_overall"]*2)+(row["goals_overall"]*4)+(row["assists_overall"]*3)+(row["penalty_goals"]*5)+(row["penalty_misses"]*-2)+(row["clean_sheets_overall"]*1)+(row['yellow_cards_overall']*-1)+(row['red_cards_overall']*-2))

#print(midfielder.apply(calculate_points,axis=1))
midfielder["Points"] = midfielder.apply(calculate_points,axis=1)

descending_midfielder = midfielder.sort_values('Points',ascending=False)
count = 2
selected_midfielder = descending_midfielder.head(5)
#for i in range(count):
    
#total_points = []
#goalkeepers["Total Points"] = ((goalkeepers["appearances_overall"]*2)+(goalkeepers["goals_overall"]*6)+(goalkeepers["assists_overall"]*3)+(goalkeepers["penalty_goals"]*5)+(goalkeepers["penalty_misses"]*-2)+(goalkeepers["clean_sheets_overall"]*4)+(goalkeepers['yellow_cards_overall']*-1)+(goalkeepers['red_cards_overall']*-2))
#print("Before")
#print(midfielder)
#print("After")
#print(descending_midfielder)
print("Selected midfielders")
print(selected_midfielder)
# Out:
# Selected midfielders
#             full_name    position       Current Club  appearances_overall  \
# 91   Luka Milivojevic  Midfielder     Crystal Palace                   38
# 6          Paul Pogba  Midfielder  Manchester United                   35
# 173  Gylfi Sigurdsson  Midfielder            Everton                   38
# 70        Ryan Fraser  Midfielder    AFC Bournemouth                   38
# 276        Leroy Sane  Midfielder    Manchester City                   31
#
#      goals_overall  assists_overall  penalty_goals  penalty_misses  \
# 91              12                2             10               1
# 6               13                9              7               3
# 173             13                6              2               3
# 70               7               13              0               0
# 276             10               10              0               0
#
#      clean_sheets_overall  yellow_cards_overall  red_cards_overall  \
# 91                     12                    10                  0
# 6                       7                     6                  0
# 173                    14                     3                  0
# 70                     10                     2                  0
# 276                    16                     1                  0
#
#      Total_Price  Points
# 91           6.7     180
# 6            8.3     179
# 173          7.3     161
# 70           6.8     151
# 276          9.3     147
# <ipython-input-6-e34565064f54>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   midfielder["Points"] = midfielder.apply(calculate_points,axis=1)

# %%
#forwards idhar daalo

forward=data_we_need[data_we_need["position"]=="Forward"]
count_row = forward.shape[0]

def calculate_points(row):
    return ((row["appearances_overall"]*2)+(row["goals_overall"]*4)+(row["assists_overall"]*3)+(row["penalty_goals"]*5)+(row["penalty_misses"]*-2)+(row["clean_sheets_overall"]*0)+(row['yellow_cards_overall']*-1)+(row['red_cards_overall']*-2))

#print(forward.apply(calculate_points,axis=1))
forward["Points"] = forward.apply(calculate_points,axis=1)

descending_forward = forward.sort_values('Points',ascending=False)
count = 2
selected_forward = descending_forward.head(3)
#for i in range(count):
    
#total_points = []
#goalkeepers["Total Points"] = ((goalkeepers["appearances_overall"]*2)+(goalkeepers["goals_overall"]*6)+(goalkeepers["assists_overall"]*3)+(goalkeepers["penalty_goals"]*5)+(goalkeepers["penalty_misses"]*-2)+(goalkeepers["clean_sheets_overall"]*4)+(goalkeepers['yellow_cards_overall']*-1)+(goalkeepers['red_cards_overall']*-2))
#print("Before")
#print(forward)
#print("After")
#print(descending_forward)
print("Selected forward")
print(selected_forward)
# Out:
# Selected forward
#                      full_name position     Current Club  appearances_overall  \
# 193              Mohamed Salah  Forward        Liverpool                   38
# 256  Pierre-Emerick Aubameyang  Forward          Arsenal                   36
# 272              Sergio Aguero  Forward  Manchester City                   33
#
#      goals_overall  assists_overall  penalty_goals  penalty_misses  \
# 193             22                8              3               0
# 256             22                5              4               1
# 272             21                8              2               0
#
#      clean_sheets_overall  yellow_cards_overall  red_cards_overall  \
# 193                    21                     1                  0
# 256                     8                     0                  0
# 272                    19                     4                  0
#
#      Total_Price  Points
# 193         12.7     202
# 256         11.1     193
# 272         11.8     180
# <ipython-input-7-3e82e2ffc274>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forward["Points"] = forward.apply(calculate_points,axis=1)

# %%
selected_goalkeepers = selected_goalkeepers.append(selected_defender,ignore_index = True)
selected_goalkeepers = selected_goalkeepers.append(selected_midfielder,ignore_index = True)
selected_goalkeepers = selected_goalkeepers.append(selected_forward,ignore_index = True)

print("Final Selected Team")
print(selected_goalkeepers)
# Out:
# Final Selected Team
#                     full_name    position       Current Club  \
# 0              Alisson Becker  Goalkeeper          Liverpool
# 1                     Ederson  Goalkeeper    Manchester City
# 2             Virgil van Dijk    Defender          Liverpool
# 3            Andrew Robertson    Defender          Liverpool
# 4             Aymeric Laporte    Defender    Manchester City
# 5      Trent Alexander-Arnold    Defender          Liverpool
# 6                 David Luiz     Defender            Chelsea
# 7            Luka Milivojevic  Midfielder     Crystal Palace
# 8                  Paul Pogba  Midfielder  Manchester United
# 9            Gylfi Sigurdsson  Midfielder            Everton
# 10                Ryan Fraser  Midfielder    AFC Bournemouth
# 11                 Leroy Sane  Midfielder    Manchester City
# 12              Mohamed Salah     Forward          Liverpool
# 13  Pierre-Emerick Aubameyang     Forward            Arsenal
# 14              Sergio Aguero     Forward    Manchester City
#
#     appearances_overall  goals_overall  assists_overall  penalty_goals  \
# 0                    38              0                0              0
# 1                    38              0                1              0
# 2                    38              4                2              0
# 3                    36              0               11              0
# 4                    35              3                3              0
# 5                    29              1               12              0
# 6                    36              3                2              0
# 7                    38             12                2             10
# 8                    35             13                9              7
# 9                    38             13                6              2
# 10                   38              7               13              0
# 11                   31             10               10              0
# 12                   38             22                8              3
# 13                   36             22                5              4
# 14                   33             21                8              2
#
#     penalty_misses  clean_sheets_overall  yellow_cards_overall  \
# 0                0                    21                     1
# 1                0                    20                     2
# 2                0                    21                     1
# 3                0                    21                     4
# 4                0                    18                     3
# 5                0                    16                     3
# 6                0                    16                     3
# 7                1                    12                    10
# 8                3                     7                     6
# 9                3                    14                     3
# 10               0                    10                     2
# 11               0                    16                     1
# 12               0                    21                     1
# 13               1                     8                     0
# 14               0                    19                     4
#
#     red_cards_overall  Total_Price  Points
# 0                   0          6.2     159
# 1                   0          6.0     157
# 2                   0          6.5     189
# 3                   0          7.0     185
# 4                   0          6.3     166
# 5                   0          7.8     161
# 6                   0          5.7     157
# 7                   0          6.7     180
# 8                   0          8.3     179
# 9                   0          7.3     161
# 10                  0          6.8     151
# 11                  0          9.3     147
# 12                  0         12.7     202
# 13                  0         11.1     193
# 14                  0         11.8     180
